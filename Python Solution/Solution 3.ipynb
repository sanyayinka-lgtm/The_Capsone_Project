# %%
product_catalog = [
    {'name': 'Television', 'description': 'visual display', 'rating': 85, 'price': 50000},
    {'name': 'Laptop', 'description': 'portable computer', 'rating': 90, 'price': 3000},
    {'name': 'Smartphone', 'description': 'mobile device', 'rating': 60, 'price': 50000},
    {'name': 'Camera', 'description': 'digital camera', 'rating': 70, 'price': 60000},
    {'name': 'Headphones', 'description': 'audio device', 'rating': 80, 'price': 2000},
    {'name': 'Heater', 'description': 'home appliance', 'rating': 75, 'price': 1500},
    {'name': 'Cooker', 'description': 'kitchen appliance', 'rating': 65, 'price': 250000},
    {'name': 'Kettle', 'description': 'kitchen appliance', 'rating': 60, 'price': 1000},
    {'name': 'Refrigerator', 'description': 'home appliance', 'rating': 85, 'price': 80000},
    {'name': 'Playstation', 'description': 'gaming console', 'rating': 90, 'price': 40000}
]
            
                      

for product in product_catalog:
    print(product['name'])
    if product['price'] > 50000:
        print(f"{product['name']} is expensive and it costs ${product['price']}.")
print(product_catalog[0]['name'])
print(product_catalog[1]['name'])
# Out:
# Television
# Laptop
# Smartphone
# Camera
# Camera is expensive and it costs $60000.
# Headphones
# Heater
# Cooker
# Cooker is expensive and it costs $250000.
# Kettle
# Refrigerator
# Refrigerator is expensive and it costs $80000.
# Playstation
# Television
# Laptop
