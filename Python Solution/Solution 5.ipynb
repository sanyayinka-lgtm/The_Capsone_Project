# %%
password = input("Enter your password: ")

while password != "python123":
    print("Incorrect password. Please try again.")
    password = input("Enter your password: ")   
print("Access granted. Welcome to the Capstone Project!")
# Out:
# Access granted. Welcome to the Capstone Project!
