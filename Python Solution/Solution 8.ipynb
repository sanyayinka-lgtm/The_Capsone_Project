# %%
prices = [5000, 12000, 8000, 15000]

updated_prices =list(map(lambda p: p * 1.075, prices))
print(f"Updated prices with 7.5% tax: {updated_prices}")
# Out:
# Updated prices with 7.5% tax: [5375.0, 12900.0, 8600.0, 16125.0]
