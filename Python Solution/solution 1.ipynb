# %%
print("The Capstone Project")
print("You are welcome to the Capstone Project!")

staff_name = input("Please enter your name: ")
branch_name = input("Please enter your branch name: ")
current_date = input("Please enter the current date (YYYY-MM-DD): ")
print(f"Hello {staff_name}, welcome to the Capstone Project!")
print(f"staff Name: {staff_name}")
print(f"Branch Name: {branch_name}")
print(f"Current Date: {current_date}")
# Out:
# The Capstone Project
# You are welcome to the Capstone Project!
# Hello Yinka, welcome to the Capstone Project!
# staff Name: Yinka
# Branch Name: Okokomiko
# Current Date: 2026-06-20
