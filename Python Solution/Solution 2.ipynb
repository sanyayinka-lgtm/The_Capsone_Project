# %%
customer =  [
    {
        "customer_id": 101,
        "customer_name": "Ada",
        "customer_age": 24,
        "gender": "Female",
        "phone_no": 8012345678,
        "is_graduated": False
    },
    {
        "customer_id": 102,
        "customer_name": "Bola",
        "customer_age": 25,
        "gender": "Female",
        "phone_no": 809876543,
        "is_graduated": False
    },
    {
        "customer_id": 103,
        "customer_name": "Chidi",
        "customer_age": 26,
        "gender": "Male",
        "phone_no": 801234567,
        "is_graduated": False
    },
    {
        "customer_id": 104,
        "customer_name": "Dayo",
        "customer_age": 27,
        "gender": "Male",
        "phone_no": 809876543,
        "is_graduated": False
    },
    {
        "customer_id": 105,
        "customer_name": "Efe",
        "customer_age": 28,
        "gender": "Female",
        "phone_no": 801234567,
        "is_graduated": False
    }
]

print("Customer Records:")
for cust in customer:
    print(cust) 
    print(cust["customer_name"])
print(customer[0]["customer_name"])
print(customer[1]["customer_name"])
print(customer[1]['customer_age'])
# Out:
# Customer Records:
# {'customer_id': 101, 'customer_name': 'Ada', 'customer_age': 24, 'gender': 'Female', 'phone_no': 8012345678, 'is_graduated': False}
# Ada
# {'customer_id': 102, 'customer_name': 'Bola', 'customer_age': 25, 'gender': 'Female', 'phone_no': 809876543, 'is_graduated': False}
# Bola
# {'customer_id': 103, 'customer_name': 'Chidi', 'customer_age': 26, 'gender': 'Male', 'phone_no': 801234567, 'is_graduated': False}
# Chidi
# {'customer_id': 104, 'customer_name': 'Dayo', 'customer_age': 27, 'gender': 'Male', 'phone_no': 809876543, 'is_graduated': False}
# Dayo
# {'customer_id': 105, 'customer_name': 'Efe', 'customer_age': 28, 'gender': 'Female', 'phone_no': 801234567, 'is_graduated': False}
# Efe
# Ada
# Bola
# 25
